# %%
import numpy as np

# %% [markdown]
# # Q1: Import matplotlib library

# %%
# write your code here ^_^
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q2: Create a one line chart using two arrays. The first array represents x and the second array represents y
# | x     |     y    |
# | ----- | -------- |
# | 1    | 1       |
# | 2    | 2       |
# | 3    | 3       |
# | 4    | 5       |
# | 5    | 8       |
# | 6    | 13      |
# | 7    | 20      |

# %%
# write your code here ^_^
x=np.array([1,2,3,4,5,6,7])
y=np.array([1,2,3,5,8,13,20])
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs. Y')
plt.show()

# %% [markdown]
# # Q3: Create a two lines chart using the same previous arrays.
# But this time:
# - Mark each point with a circle.
# - Use dashed lines.
# - Set the size of the marker (circle) to size 10.
# - Set the width of the line to 3.
# - Add legends. 'Normal' for array x and 'Fast' for array y.

# %%
# write your code here ^_^
plt.plot(x,marker=".", markersize=10)
plt.plot(y,linestyle = 'dashed',linewidth = 3)
plt.legend(['circle','dashed'], shadow = True, loc = 0) # location (0 = best)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs. Y')
plt.show()

# %% [markdown]
# # Q4: Display multiple linear charts in one row using the charts given below.
# - Give each chart a title
# - Add a super title 'my data visulaization assignment'.

# %%
#super title = my data visulaization assignment
plt.figure(figsize=[20,10])
plt.suptitle('My data visulaization assignment',fontsize = 20)


#title = First Chart
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])
plt.subplot(1,3,1)
plt.xlabel('x_plot1')
plt.ylabel('y_plot1')
plt.title('X vs. Y')
plt.plot(x_plot1,y_plot1,marker=".", markersize=10)


#title = Second Chart
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])
plt.subplot(1,3,2)
plt.xlabel('x_plot1')
plt.ylabel('y_plot1')
plt.title('X vs. Y')
plt.plot(x_plot2,y_plot2,marker=".", markersize=10)

#title = Third Chart
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])
plt.subplot(1,3,3)
plt.xlabel('x_plot1')
plt.ylabel('y_plot1')
plt.title('X vs. Y')
plt.plot(x_plot3,y_plot3,marker=".", markersize=10)

# %%
# write your code here ^_^
#super title = my data visulaization assignment
#title = First Chart
x_plot1 = np.array([1, 2, 3, 4, 5, 6, 7])
y_plot1 = np.array([1, 1, 2, 3, 5, 8, 13])
plt.subplot(1,3,1)
plt.plot(x_plot1,y_plot1,marker=".", markersize=10)

#title = Second Chart
x_plot2 = np.array([0, 1, 2, 3, 4, 5, 6])
y_plot2 = np.array([2, 4, 6, 8, 10, 12, 14])
plt.plot(x_plot2,y_plot2,marker=".", markersize=10)

#title = Third Chart
x_plot3 = np.array([0, 1, 3, 4])
y_plot3 = np.array([4, 6, 3, 4])
plt.plot(x_plot3,y_plot3,marker=".", markersize=10)
plt.xlabel('x_plot1')
plt.ylabel('y_plot1')
plt.title('X vs. Y')
plt.show()

# %% [markdown]
# # Q5: Define an array that has a values of your top three TV series and define another array to hold the rating of the three TV series out of 10. Create a bar chart using the two arrays
# - Set a new color for the bars.
# - Change the width of the bars to width 0.5.

# %%
# write your code here ^_^
tvSeries=['Planet Earth','Band of Brothers ','Chernobyl']
rating=[8.7,5,5]

colors = ['#ff9999','#FBEC5D','#FAF0E6']

plt.bar(tvSeries, rating, color= colors,width = 0.5)
plt.title('Top Three TV Series',fontsize = 20)
plt.xlabel('TV Series',fontsize = 20)
plt.ylabel('Rating',fontsize = 20)
plt.grid()
plt.show()

# %% [markdown]
# # Q6: Create a scatter plot  using two arrays. The first array represents carAge and the second array represents carSpeed, set a specific color for each dot by using an array of different colors and add labels for the plot
# | carAge | carSpeed |
# | ----- | -------- |
# | 5    | 99       |
# | 7    | 86       |
# | 8    |87      |
# | 7    | 88       |
# | 2    | 111       |
# | 17    | 86       |
# | 2    | 103      |
# | 9    | 87       |
# | 4    | 94       |
# | 11    | 78      |

# %% [markdown]
# - Set a new color for each dot by using an array of different colors.
# - Change the size of the dots to size 350.
# - Add labels for x-axis and y-axis.
# - Adjust the transparency of the dots with the alpha argument. let the alpha value be 0.4

# %%
# write your code here ^_^
carAge=[1,7,8,7,2,17,2,9,4,11]
carSpeed=[99,86,87,88,111,86,103,87,94,78]
colors = ['#ff9999','#66b3ff','#99ff99','#FFFACD','#FFB6C1','#C8A2C8','#FAF0E6','#FBEC5D','#CC3333','#997A8D']

plt.scatter(carAge,carSpeed,alpha = 0.4,s = 350,color=colors) 

plt.title('car Age vs. car Speed',fontsize = 20)
plt.xlabel('car Age',fontsize = 20)
plt.ylabel('car Speed',fontsize = 20)


plt.show()

# %% [markdown]
# # Q7: Create a pie chart using two arrays. The first array represents python_libraries and the second array represents your skills out of 10 at each library
# | python_libraries |
# | ------------ |
# | NumPy        |
# | Pandas       |
# | Matplotlib   |
# | Seaborn      |
# | Plotly       |
# | Scikit-learn |

# %% [markdown]
# - Set a new color for each wedge by using an array of different colors.
# - Pull your favorite library wedge 0.3 from the center of the pie.
# - Add a shadow to the pie chart

# %%
# write your code here ^_^
python_libraries=['NumPy','Pandas','Matplotlib','Seaborn','Plotly','Scikit-learn']
carSpeed=[8,8,9,6,5,4]
colors = ['#ff9999','#FBEC5D','#FAF0E6','#FFFACD','#FFB6C1','#C8A2C8']

plt.pie(carSpeed,labels=python_libraries, autopct='%1.f%%',colors =colors,  startangle=180, radius=1.5,
        explode = [0,0,0.3,0,0,0],shadow=True)

plt.show()

# %% [markdown]
# # Q8: Create a histogram with 250 values and 15 bars

# %%
# write your code here ^_^
x = np.random.normal(170, 10, 250)
plt.hist(x, bins = 15,facecolor = '#ff9999',edgecolor = '#FAF0E6')
plt.xlabel('Values')
plt.ylabel('Bars')
plt.title('Values and Bars')
plt.show()
